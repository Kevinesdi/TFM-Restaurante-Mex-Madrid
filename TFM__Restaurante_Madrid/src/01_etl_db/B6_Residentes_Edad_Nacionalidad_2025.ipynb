# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
usuario = 'postgres'
contraseña = 'postgre'
host = 'localhost'
puerto = '5432'
base_de_datos = 'postgres'

# %%
conexion = f'postgresql+psycopg2://{usuario}:{contraseña}@{host}:{puerto}/{base_de_datos}'

# %%
conn = create_engine(conexion)

# %%
conn
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/postgres)

# %%
try:
    version = pd.read_sql("SELECT version();", conn).iloc[0, 0]
    print("Conexión exitosa con SQLAlchemy.")
    print(f"Versión del servidor PostgreSQL: {version}")
except Exception as e:
    print(f"Ocurrió un error al conectar con SQLAlchemy: {e}")
# Out:
# Conexión exitosa con SQLAlchemy.
# Versión del servidor PostgreSQL: PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.43.34808, 64-bit

# %%
consulta_1 = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'dw_tfm_restaurantes'
ORDER BY table_name;
"""
pd.read_sql(consulta_1, conn)
# Out:
#                table_name
# 0           aparcamientos
# 1              dim_barrio
# 2            dim_distrito
# 3          flujo_peatones
# 4               licencias
# 5    menu_restaurantes_mx
# 6        poblacion_madrid
# 7   residentes_demografia
# 8            restaurantes
# 9                terrazas
# 10     transporte_publico

# %%
consulta_2 = """
SELECT *
FROM 
  information_schema.columns 
WHERE 
  table_name = 'residentes_demografia';
"""
pd.read_sql(consulta_2, conn)
# Out:
#    table_catalog         table_schema             table_name  \
# 0       postgres  dw_tfm_restaurantes  residentes_demografia
# 1       postgres  dw_tfm_restaurantes  residentes_demografia
# 2       postgres  dw_tfm_restaurantes  residentes_demografia
# 3       postgres  dw_tfm_restaurantes  residentes_demografia
# 4       postgres  dw_tfm_restaurantes  residentes_demografia
# 5       postgres  dw_tfm_restaurantes  residentes_demografia
# 6       postgres  dw_tfm_restaurantes  residentes_demografia
# 7       postgres  dw_tfm_restaurantes  residentes_demografia
# 8       postgres  dw_tfm_restaurantes  residentes_demografia
# 9       postgres  dw_tfm_restaurantes  residentes_demografia
# 10      postgres  dw_tfm_restaurantes  residentes_demografia
# 11      postgres  dw_tfm_restaurantes  residentes_demografia
# 12      postgres  dw_tfm_restaurantes  residentes_demografia
# 13      postgres  dw_tfm_restaurantes  residentes_demografia
# 14      postgres  dw_tfm_restaurantes  residentes_demografia
# 15      postgres  dw_tfm_restaurantes  residentes_demografia
#
#             column_name  ordinal_position  \
# 0         id_demografia                 1
# 1          cod_distrito                 2
# 2         desc_distrito                 3
# 3       cod_dist_barrio                 4
# 4           desc_barrio                 5
# 5            cod_barrio                 6
# 6      cod_dist_seccion                 7
# 7           cod_seccion                 8
# 8          cod_edad_int                 9
# 9     espanoles_hombres                10
# 10    espanoles_mujeres                11
# 11  extranjeros_hombres                12
# 12  extranjeros_mujeres                13
# 13             fx_carga                14
# 14         fx_datos_ini                15
# 15         fx_datos_fin                16
#
#                                        column_default is_nullable  \
# 0   nextval('dw_tfm_restaurantes.residentes_demogr...          NO
# 1                                                None         YES
# 2                                                None         YES
# 3                                                None         YES
# 4                                                None         YES
# 5                                                None         YES
# 6                                                None         YES
# 7                                                None         YES
# 8                                                None         YES
# 9                                                None         YES
# 10                                               None         YES
# 11                                               None         YES
# 12                                               None         YES
# 13                                               None         YES
# 14                                               None         YES
# 15                                               None         YES
#
#             data_type  character_maximum_length  character_octet_length  ...  \
# 0             integer                       NaN                     NaN  ...
# 1             integer                       NaN                     NaN  ...
# 2   character varying                     100.0                   400.0  ...
# 3             integer                       NaN                     NaN  ...
# 4   character varying                     100.0                   400.0  ...
# 5             integer                       NaN                     NaN  ...
# 6             integer                       NaN                     NaN  ...
# 7             integer                       NaN                     NaN  ...
# 8             integer                       NaN                     NaN  ...
# 9             integer                       NaN                     NaN  ...
# 10            integer                       NaN                     NaN  ...
# 11            integer                       NaN                     NaN  ...
# 12            integer                       NaN                     NaN  ...
# 13  character varying                      50.0                   200.0  ...
# 14  character varying                      50.0                   200.0  ...
# 15  character varying                      50.0                   200.0  ...
#
#     is_identity  identity_generation  identity_start identity_increment  \
# 0            NO                 None            None               None
# 1            NO                 None            None               None
# 2            NO                 None            None               None
# 3            NO                 None            None               None
# 4            NO                 None            None               None
# 5            NO                 None            None               None
# 6            NO                 None            None               None
# 7            NO                 None            None               None
# 8            NO                 None            None               None
# 9            NO                 None            None               None
# 10           NO                 None            None               None
# 11           NO                 None            None               None
# 12           NO                 None            None               None
# 13           NO                 None            None               None
# 14           NO                 None            None               None
# 15           NO                 None            None               None
#
#    identity_maximum identity_minimum identity_cycle is_generated  \
# 0              None             None             NO        NEVER
# 1              None             None             NO        NEVER
# 2              None             None             NO        NEVER
# 3              None             None             NO        NEVER
# 4              None             None             NO        NEVER
# 5              None             None             NO        NEVER
# 6              None             None             NO        NEVER
# 7              None             None             NO        NEVER
# 8              None             None             NO        NEVER
# 9              None             None             NO        NEVER
# 10             None             None             NO        NEVER
# 11             None             None             NO        NEVER
# 12             None             None             NO        NEVER
# 13             None             None             NO        NEVER
# 14             None             None             NO        NEVER
# 15             None             None             NO        NEVER
#
#    generation_expression is_updatable
# 0                   None          YES
# 1                   None          YES
# 2                   None          YES
# 3                   None          YES
# 4                   None          YES
# 5                   None          YES
# 6                   None          YES
# 7                   None          YES
# 8                   None          YES
# 9                   None          YES
# 10                  None          YES
# 11                  None          YES
# 12                  None          YES
# 13                  None          YES
# 14                  None          YES
# 15                  None          YES
#
# [16 rows x 44 columns]

# %%
consulta_3= """
SELECT 
  column_name, 
  data_type, 
  character_maximum_length, 
  is_nullable, 
  column_default 
FROM 
  information_schema.columns 
WHERE 
  table_name = 'residentes_demografia'
ORDER BY
    ordinal_position
"""

pd.read_sql(consulta_3, conn)
# Out:
#             column_name          data_type  character_maximum_length  \
# 0         id_demografia            integer                       NaN
# 1          cod_distrito            integer                       NaN
# 2         desc_distrito  character varying                     100.0
# 3       cod_dist_barrio            integer                       NaN
# 4           desc_barrio  character varying                     100.0
# 5            cod_barrio            integer                       NaN
# 6      cod_dist_seccion            integer                       NaN
# 7           cod_seccion            integer                       NaN
# 8          cod_edad_int            integer                       NaN
# 9     espanoles_hombres            integer                       NaN
# 10    espanoles_mujeres            integer                       NaN
# 11  extranjeros_hombres            integer                       NaN
# 12  extranjeros_mujeres            integer                       NaN
# 13             fx_carga  character varying                      50.0
# 14         fx_datos_ini  character varying                      50.0
# 15         fx_datos_fin  character varying                      50.0
#
#    is_nullable                                     column_default
# 0           NO  nextval('dw_tfm_restaurantes.residentes_demogr...
# 1          YES                                               None
# 2          YES                                               None
# 3          YES                                               None
# 4          YES                                               None
# 5          YES                                               None
# 6          YES                                               None
# 7          YES                                               None
# 8          YES                                               None
# 9          YES                                               None
# 10         YES                                               None
# 11         YES                                               None
# 12         YES                                               None
# 13         YES                                               None
# 14         YES                                               None
# 15         YES                                               None

# %% [markdown]
# Leer fichero

# %%
df_residentes_demografia = pd.read_csv("./ficheros/B6_Residentes_Edad_Nacionalidad_2025.csv")
df_residentes_demografia.head(10)
# Out:
#    COD_DISTRITO         DESC_DISTRITO  COD_DIST_BARRIO           DESC_BARRIO  \
# 0             2  ARGANZUELA                      202.0  ACACIAS
# 1            16  HORTALEZA                      1604.0  PINAR DEL REY
# 2             3  RETIRO                          306.0  NIÑO JESUS
# 3             8  FUENCARRAL-EL PARDO             803.0  PEÑA GRANDE
# 4            10  LATINA                         1003.0  LUCERO
# 5             2  ARGANZUELA                      205.0  DELICIAS
# 6             2  ARGANZUELA                      204.0  LEGAZPI
# 7            13  PUENTE DE VALLECAS             1302.0  SAN DIEGO
# 8            17  VILLAVERDE                     1705.0  ANGELES
# 9             2  ARGANZUELA                      206.0  PALOS DE LA FRONTERA
#
#    COD_BARRIO  COD_DIST_SECCION  COD_SECCION  COD_EDAD_INT  ESPANOLES_HOMBRES  \
# 0         2.0            2094.0         94.0            47                  7
# 1         4.0           16073.0         73.0            59                  3
# 2         6.0            3080.0         80.0            60                  7
# 3         3.0            8025.0         25.0            57                  5
# 4         3.0           10057.0         57.0            60                  8
# 5         5.0            2062.0         62.0            71                  3
# 6         4.0            2111.0        111.0            77                  2
# 7         2.0           13062.0         62.0            19                  1
# 8         5.0           17092.0         92.0             3                  1
# 9         6.0            2065.0         65.0             1                  4
#
#    ESPANOLES_MUJERES  EXTRANJEROS_HOMBRES  EXTRANJEROS_MUJERES FX_CARGA  \
# 0                  8                    0                    0  00:01.6
# 1                 15                    0                    1  00:01.6
# 2                 18                    0                    1  00:01.6
# 3                  8                    1                    0  00:01.6
# 4                  9                    2                    3  00:01.6
# 5                  5                    1                    1  00:01.6
# 6                  1                    0                    0  00:01.6
# 7                  2                    3                    4  00:01.6
# 8                  3                    1                    0  00:01.6
# 9                  4                    2                    1  00:01.6
#
#   FX_DATOS_INI FX_DATOS_FIN
# 0   01/08/2025   01/08/2025
# 1   01/08/2025   01/08/2025
# 2   01/08/2025   01/08/2025
# 3   01/08/2025   01/08/2025
# 4   01/08/2025   01/08/2025
# 5   01/08/2025   01/08/2025
# 6   01/08/2025   01/08/2025
# 7   01/08/2025   01/08/2025
# 8   01/08/2025   01/08/2025
# 9   01/08/2025   01/08/2025

# %%
# Normalizamos a minusculas los títulos
df_residentes_demografia.columns = df_residentes_demografia.columns.str.lower().str.replace(' ', '_')

# %%
df_residentes_demografia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240770 entries, 0 to 240769
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   cod_distrito         240770 non-null  int64
#  1   desc_distrito        240770 non-null  object
#  2   cod_dist_barrio      240765 non-null  float64
#  3   desc_barrio          240765 non-null  object
#  4   cod_barrio           240765 non-null  float64
#  5   cod_dist_seccion     240763 non-null  float64
#  6   cod_seccion          240763 non-null  float64
#  7   cod_edad_int         240770 non-null  int64
#  8   espanoles_hombres    240770 non-null  int64
#  9   espanoles_mujeres    240770 non-null  int64
#  10  extranjeros_hombres  240770 non-null  int64
#  11  extranjeros_mujeres  240770 non-null  int64
#  12  fx_carga             240770 non-null  object
#  13  fx_datos_ini         240770 non-null  object
#  14  fx_datos_fin         240770 non-null  object
# dtypes: float64(4), int64(6), object(5)
# memory usage: 27.6+ MB

# %%
df_rango_edad.describe(include="all").T
# Out:
#                        count unique                   top    freq  \
# COD_DISTRITO        240770.0    NaN                   NaN     NaN
# DESC_DISTRITO         240770     21  LATINA                 19229
# COD_DIST_BARRIO     240765.0    NaN                   NaN     NaN
# DESC_BARRIO           240765    131  ALUCHE                  5590
# COD_BARRIO          240765.0    NaN                   NaN     NaN
# COD_DIST_SECCION    240763.0    NaN                   NaN     NaN
# COD_SECCION         240763.0    NaN                   NaN     NaN
# COD_EDAD_INT        240770.0    NaN                   NaN     NaN
# ESPANOLESHOMBRES    240770.0    NaN                   NaN     NaN
# ESPANOLESMUJERES    240770.0    NaN                   NaN     NaN
# EXTRANJEROSHOMBRES  240770.0    NaN                   NaN     NaN
# EXTRANJEROSMUJERES  240770.0    NaN                   NaN     NaN
# FX_CARGA              240770      1               00:01.6  240770
# FX_DATOS_INI          240770      1            01/08/2025  240770
# FX_DATOS_FIN          240770      1            01/08/2025  240770
#
#                            mean          std     min     25%      50%  \
# COD_DISTRITO          10.415911     5.431066     1.0     6.0     10.0
# DESC_DISTRITO               NaN          NaN     NaN     NaN      NaN
# COD_DIST_BARRIO     1045.176508   543.082481   101.0   604.0   1007.0
# DESC_BARRIO                 NaN          NaN     NaN     NaN      NaN
# COD_BARRIO             3.605267     1.872978     1.0     2.0      4.0
# COD_DIST_SECCION    10490.04411  5431.882015  1001.0  6078.0  10194.0
# COD_SECCION           74.295012    51.186987     1.0    33.0     66.0
# COD_EDAD_INT          48.511845    28.366215     0.0    24.0     48.0
# ESPANOLESHOMBRES       5.479931     4.593367     0.0     2.0      5.0
# ESPANOLESMUJERES       6.258732     4.774843     0.0     3.0      5.0
# EXTRANJEROSHOMBRES     1.357092     2.206902     0.0     0.0      0.0
# EXTRANJEROSMUJERES     1.464601     2.179726     0.0     0.0      1.0
# FX_CARGA                    NaN          NaN     NaN     NaN      NaN
# FX_DATOS_INI                NaN          NaN     NaN     NaN      NaN
# FX_DATOS_FIN                NaN          NaN     NaN     NaN      NaN
#
#                         75%      max
# COD_DISTRITO           15.0     21.0
# DESC_DISTRITO           NaN      NaN
# COD_DIST_BARRIO      1502.0   2105.0
# DESC_BARRIO             NaN      NaN
# COD_BARRIO              5.0      9.0
# COD_DIST_SECCION    15061.0  21034.0
# COD_SECCION           106.0    222.0
# COD_EDAD_INT           73.0    100.0
# ESPANOLESHOMBRES        7.0     73.0
# ESPANOLESMUJERES        8.0     69.0
# EXTRANJEROSHOMBRES      2.0     66.0
# EXTRANJEROSMUJERES      2.0     68.0
# FX_CARGA                NaN      NaN
# FX_DATOS_INI            NaN      NaN
# FX_DATOS_FIN            NaN      NaN

# %%
df_residentes_demografia.isnull().sum()
# Out:
# cod_distrito           0
# desc_distrito          0
# cod_dist_barrio        5
# desc_barrio            5
# cod_barrio             5
# cod_dist_seccion       7
# cod_seccion            7
# cod_edad_int           0
# espanoles_hombres      0
# espanoles_mujeres      0
# extranjeros_hombres    0
# extranjeros_mujeres    0
# fx_carga               0
# fx_datos_ini           0
# fx_datos_fin           0
# dtype: int64

# %% [markdown]
# Duplicados para eliminar

# %%
df_residentes_demografia.duplicated().values.any()
# Out:
# np.False_

# %% [markdown]
# Volcado Datos

# %%
df_residentes_demografia.to_sql('residentes_demografia', schema='dw_tfm_restaurantes', con = conn, if_exists = 'append', index=False)
# Out:
# 770

# %%
count_db = pd.read_sql("SELECT COUNT(*) AS count FROM dw_tfm_restaurantes.residentes_demografia", conn).iloc[0, 0]
count_df = len(df_rango_edad)

print(f"Filas en DataFrame: {count_df}")
print(f"Filas en tabla dw_tfm_restaurantes: {count_db}")

if count_df == count_db:
    print("La carga se efectuó correctamente.")
else:
    print("Hay discrepancias en la cantidad de filas insertadas.")
# Out:
# Filas en DataFrame: 240770
# Filas en tabla dw_tfm_restaurantes: 240770
# La carga se efectuó correctamente.
