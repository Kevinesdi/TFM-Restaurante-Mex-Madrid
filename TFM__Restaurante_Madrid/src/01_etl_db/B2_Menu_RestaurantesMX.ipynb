# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
usuario = 'postgres'
contraseña = 'postgre'
host = 'localhost'
puerto = '5432'
base_de_datos = 'postgres'

# %%
conexion = f'postgresql+psycopg2://{usuario}:{contraseña}@{host}:{puerto}/{base_de_datos}'

# %%
conn = create_engine(conexion)

# %%
conn
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/postgres)

# %%
try:
    version = pd.read_sql("SELECT version();", conn).iloc[0, 0]
    print("Conexión exitosa con SQLAlchemy.")
    print(f"Versión del servidor PostgreSQL: {version}")
except Exception as e:
    print(f"Ocurrió un error al conectar con SQLAlchemy: {e}")
# Out:
# Conexión exitosa con SQLAlchemy.
# Versión del servidor PostgreSQL: PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.43.34808, 64-bit

# %%
consulta_1 = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'dw_tfm_restaurantes'
ORDER BY table_name;
"""
pd.read_sql(consulta_1, conn)
# Out:
#                table_name
# 0           aparcamientos
# 1              dim_barrio
# 2            dim_distrito
# 3          flujo_peatones
# 4               licencias
# 5    menu_restaurantes_mx
# 6        poblacion_madrid
# 7   residentes_demografia
# 8            restaurantes
# 9                terrazas
# 10     transporte_publico

# %%
consulta_2 = """
SELECT *
FROM 
  information_schema.columns 
WHERE 
  table_name = 'menu_restaurantes_mx';
"""
pd.read_sql(consulta_2, conn)
# Out:
#   table_catalog         table_schema            table_name       column_name  \
# 0      postgres  dw_tfm_restaurantes  menu_restaurantes_mx          id_plato
# 1      postgres  dw_tfm_restaurantes  menu_restaurantes_mx          id_local
# 2      postgres  dw_tfm_restaurantes  menu_restaurantes_mx            rotulo
# 3      postgres  dw_tfm_restaurantes  menu_restaurantes_mx            platos
# 4      postgres  dw_tfm_restaurantes  menu_restaurantes_mx            precio
# 5      postgres  dw_tfm_restaurantes  menu_restaurantes_mx         estrellas
# 6      postgres  dw_tfm_restaurantes  menu_restaurantes_mx  numero_opiniones
# 7      postgres  dw_tfm_restaurantes  menu_restaurantes_mx             calle
#
#    ordinal_position                                     column_default  \
# 0                 1  nextval('dw_tfm_restaurantes.menu_restaurantes...
# 1                 2                                               None
# 2                 3                                               None
# 3                 4                                               None
# 4                 5                                               None
# 5                 6                                               None
# 6                 7                                               None
# 7                 8                                               None
#
#   is_nullable          data_type  character_maximum_length  \
# 0          NO            integer                       NaN
# 1         YES             bigint                       NaN
# 2         YES  character varying                     255.0
# 3         YES               text                       NaN
# 4         YES   double precision                       NaN
# 5         YES   double precision                       NaN
# 6         YES            integer                       NaN
# 7         YES  character varying                     255.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                     NaN  ...           NO                 None
# 2            1.020000e+03  ...           NO                 None
# 3            1.073742e+09  ...           NO                 None
# 4                     NaN  ...           NO                 None
# 5                     NaN  ...           NO                 None
# 6                     NaN  ...           NO                 None
# 7            1.020000e+03  ...           NO                 None
#
#    identity_start identity_increment identity_maximum identity_minimum  \
# 0            None               None             None             None
# 1            None               None             None             None
# 2            None               None             None             None
# 3            None               None             None             None
# 4            None               None             None             None
# 5            None               None             None             None
# 6            None               None             None             None
# 7            None               None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
#
# [8 rows x 44 columns]

# %%
consulta_3= """
SELECT 
  column_name, 
  data_type, 
  character_maximum_length, 
  is_nullable, 
  column_default 
FROM 
  information_schema.columns 
WHERE 
  table_name = 'menu_restaurantes_mx'
ORDER BY
    ordinal_position
"""

pd.read_sql(consulta_3, conn)
# Out:
#         column_name          data_type  character_maximum_length is_nullable  \
# 0          id_plato            integer                       NaN          NO
# 1          id_local             bigint                       NaN         YES
# 2            rotulo  character varying                     255.0         YES
# 3            platos               text                       NaN         YES
# 4            precio   double precision                       NaN         YES
# 5         estrellas   double precision                       NaN         YES
# 6  numero_opiniones            integer                       NaN         YES
# 7             calle  character varying                     255.0         YES
#
#                                       column_default
# 0  nextval('dw_tfm_restaurantes.menu_restaurantes...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None

# %% [markdown]
# Leer fichero

# %%
df_rest_precios = pd.read_excel("./ficheros/B2_Menu_RestaurantesMX.xlsx")
df_rest_precios.head(10)
# Out:
#    id_local      rotulo                                platos  precio  \
# 0  10000105  LA MORDIDA                  Nachos con guacamole    16.9
# 1  10000105  LA MORDIDA                      Flautas de pollo     8.9
# 2  10000105  LA MORDIDA                    Chilaquiles verdes    14.9
# 3  10000105  LA MORDIDA                    Jalapeños rellenos     9.9
# 4  10000105  LA MORDIDA                                Pozole     9.9
# 5  10000105  LA MORDIDA                           Quesadillas     9.9
# 6  10000105  LA MORDIDA     Enchiladas de pollo en salsa rojo    14.9
# 7  10000105  LA MORDIDA  Enchiladas de pollo con mole poblano    14.9
# 8  10000105  LA MORDIDA                        4 tacos pastor    14.5
# 9  10000105  LA MORDIDA                      4 tacos carnitas    13.5
#
#    estrellas  numero_opiniones  \
# 0        4.4              2731
# 1        4.4              2731
# 2        4.4              2731
# 3        4.4              2731
# 4        4.4              2731
# 5        4.4              2731
# 6        4.4              2731
# 7        4.4              2731
# 8        4.4              2731
# 9        4.4              2731
#
#                                                calle
# 0  BELEN                                         ...
# 1  BELEN                                         ...
# 2  BELEN                                         ...
# 3  BELEN                                         ...
# 4  BELEN                                         ...
# 5  BELEN                                         ...
# 6  BELEN                                         ...
# 7  BELEN                                         ...
# 8  BELEN                                         ...
# 9  BELEN                                         ...

# %%
df_rest_precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_local          1534 non-null   int64
#  1   rotulo            1534 non-null   object
#  2   platos            1534 non-null   object
#  3   precio            1534 non-null   float64
#  4   estrellas         1534 non-null   float64
#  5   numero_opiniones  1534 non-null   int64
#  6   calle             1521 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 84.0+ KB

# %%
df_rest_precios.describe(include="all").T
# Out:
#                    count unique  \
# id_local          1534.0    NaN
# rotulo              1534     42
# platos              1534    510
# precio            1534.0    NaN
# estrellas         1534.0    NaN
# numero_opiniones  1534.0    NaN
# calle               1521     72
#
#                                                                 top freq  \
# id_local                                                        NaN  NaN
# rotulo                                                    TACO BELL  357
# platos                                                    Michelada   36
# precio                                                          NaN  NaN
# estrellas                                                       NaN  NaN
# numero_opiniones                                                NaN  NaN
# calle             FUENTES                                       ...   59
#
#                               mean              std         min          25%  \
# id_local          233629354.326597  90974086.010944  10000105.0  270080421.0
# rotulo                         NaN              NaN         NaN          NaN
# platos                         NaN              NaN         NaN          NaN
# precio                     9.14264         5.329168         1.0          4.5
# estrellas                 4.255411         0.353244         3.5          4.0
# numero_opiniones       1833.290091      1868.136399        34.0        485.0
# calle                          NaN              NaN         NaN          NaN
#
#                           50%          75%          max
# id_local          270536971.0  280039701.0  290000158.0
# rotulo                    NaN          NaN          NaN
# platos                    NaN          NaN          NaN
# precio                    8.6         12.9         33.5
# estrellas                 4.3          4.5          4.9
# numero_opiniones       1185.5       2276.0       9788.0
# calle                     NaN          NaN          NaN

# %%
df_rest_precios.isnull().sum()
# Out:
# id_local             0
# rotulo               0
# platos               0
# precio               0
# estrellas            0
# numero_opiniones     0
# calle               13
# dtype: int64

# %% [markdown]
# Duplicados para eliminar

# %%
df_rest_precios.duplicated().values.any()
# Out:
# np.False_

# %% [markdown]
# Volcado Datos

# %%
df_rest_precios.to_sql('menu_restaurantes_mx', schema='dw_tfm_restaurantes', con = conn, if_exists = 'append', index=False)
# Out:
# 534

# %%
count_db = pd.read_sql("SELECT COUNT(*) AS count FROM dw_tfm_restaurantes.menu_restaurantes_mx", conn).iloc[0, 0]
count_df = len(df_rest_precios)

print(f"Filas en DataFrame: {count_df}")
print(f"Filas en tabla dw_tfm_restaurantes: {count_db}")

if count_df == count_db:
    print("La carga se efectuó correctamente.")
else:
    print("Hay discrepancias en la cantidad de filas insertadas.")
# Out:
# Filas en DataFrame: 1534
# Filas en tabla dw_tfm_restaurantes: 1534
# La carga se efectuó correctamente.
