# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
usuario = 'postgres'
contraseña = 'postgre'
host = 'localhost'
puerto = '5432'
base_de_datos = 'postgres'

# %%
conexion = f'postgresql+psycopg2://{usuario}:{contraseña}@{host}:{puerto}/{base_de_datos}'

# %%
conn = create_engine(conexion)

# %%
conn
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/postgres)

# %%
try:
    version = pd.read_sql("SELECT version();", conn).iloc[0, 0]
    print("Conexión exitosa con SQLAlchemy.")
    print(f"Versión del servidor PostgreSQL: {version}")
except Exception as e:
    print(f"Ocurrió un error al conectar con SQLAlchemy: {e}")
# Out:
# Conexión exitosa con SQLAlchemy.
# Versión del servidor PostgreSQL: PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.43.34808, 64-bit

# %%
consulta_1 = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'dw_tfm_restaurantes'
ORDER BY table_name;
"""
pd.read_sql(consulta_1, conn)
# Out:
#                table_name
# 0           aparcamientos
# 1              dim_barrio
# 2            dim_distrito
# 3          flujo_peatones
# 4               licencias
# 5    menu_restaurantes_mx
# 6        poblacion_madrid
# 7   residentes_demografia
# 8            restaurantes
# 9                terrazas
# 10     transporte_publico

# %%
consulta_2 = """
SELECT *
FROM 
  information_schema.columns 
WHERE 
  table_name = 'flujo_peatones';
"""
pd.read_sql(consulta_2, conn)
# Out:
#   table_catalog         table_schema      table_name  \
# 0      postgres  dw_tfm_restaurantes  flujo_peatones
# 1      postgres  dw_tfm_restaurantes  flujo_peatones
# 2      postgres  dw_tfm_restaurantes  flujo_peatones
# 3      postgres  dw_tfm_restaurantes  flujo_peatones
# 4      postgres  dw_tfm_restaurantes  flujo_peatones
# 5      postgres  dw_tfm_restaurantes  flujo_peatones
# 6      postgres  dw_tfm_restaurantes  flujo_peatones
# 7      postgres  dw_tfm_restaurantes  flujo_peatones
# 8      postgres  dw_tfm_restaurantes  flujo_peatones
#
#                 column_name  ordinal_position  \
# 0        id_registro_peaton                 1
# 1            fecha_peatones                 2
# 2             hora_peatones                 3
# 3         cantidad_peatones                 4
# 4  numero_distrito_peatones                 5
# 5                  distrito                 6
# 6                 direccion                 7
# 7                   latitud                 8
# 8                  longitud                 9
#
#                                       column_default is_nullable  \
# 0  nextval('dw_tfm_restaurantes.flujo_peatones_id...          NO
# 1                                               None         YES
# 2                                               None         YES
# 3                                               None         YES
# 4                                               None         YES
# 5                                               None         YES
# 6                                               None         YES
# 7                                               None         YES
# 8                                               None         YES
#
#                 data_type  character_maximum_length  character_octet_length  \
# 0                 integer                       NaN                     NaN
# 1                    date                       NaN                     NaN
# 2  time without time zone                       NaN                     NaN
# 3                 integer                       NaN                     NaN
# 4                 integer                       NaN                     NaN
# 5       character varying                     100.0                   400.0
# 6       character varying                     255.0                  1020.0
# 7       character varying                      50.0                   200.0
# 8       character varying                      50.0                   200.0
#
#    ...  is_identity  identity_generation  identity_start  identity_increment  \
# 0  ...           NO                 None            None                None
# 1  ...           NO                 None            None                None
# 2  ...           NO                 None            None                None
# 3  ...           NO                 None            None                None
# 4  ...           NO                 None            None                None
# 5  ...           NO                 None            None                None
# 6  ...           NO                 None            None                None
# 7  ...           NO                 None            None                None
# 8  ...           NO                 None            None                None
#
#   identity_maximum identity_minimum identity_cycle is_generated  \
# 0             None             None             NO        NEVER
# 1             None             None             NO        NEVER
# 2             None             None             NO        NEVER
# 3             None             None             NO        NEVER
# 4             None             None             NO        NEVER
# 5             None             None             NO        NEVER
# 6             None             None             NO        NEVER
# 7             None             None             NO        NEVER
# 8             None             None             NO        NEVER
#
#   generation_expression is_updatable
# 0                  None          YES
# 1                  None          YES
# 2                  None          YES
# 3                  None          YES
# 4                  None          YES
# 5                  None          YES
# 6                  None          YES
# 7                  None          YES
# 8                  None          YES
#
# [9 rows x 44 columns]

# %%
consulta_3= """
SELECT 
  column_name, 
  data_type, 
  character_maximum_length, 
  is_nullable, 
  column_default 
FROM 
  information_schema.columns 
WHERE 
  table_name = 'flujo_peatones'
ORDER BY
    ordinal_position
"""

pd.read_sql(consulta_3, conn)
# Out:
#                 column_name               data_type  character_maximum_length  \
# 0        id_registro_peaton                 integer                       NaN
# 1            fecha_peatones                    date                       NaN
# 2             hora_peatones  time without time zone                       NaN
# 3         cantidad_peatones                 integer                       NaN
# 4  numero_distrito_peatones                 integer                       NaN
# 5                  distrito       character varying                     100.0
# 6                 direccion       character varying                     255.0
# 7                   latitud       character varying                      50.0
# 8                  longitud       character varying                      50.0
#
#   is_nullable                                     column_default
# 0          NO  nextval('dw_tfm_restaurantes.flujo_peatones_id...
# 1         YES                                               None
# 2         YES                                               None
# 3         YES                                               None
# 4         YES                                               None
# 5         YES                                               None
# 6         YES                                               None
# 7         YES                                               None
# 8         YES                                               None

# %% [markdown]
# Leer fichero

# %%
df_peatones = pd.read_excel("./ficheros/B4_Flujo_Peatones_2024 .xlsx")
df_peatones.head(10)
# Out:
#        fecha_peatones hora_peatones  cantidad_peatones  \
# 0 2024-01-01 00:00:00      00:00:00                910
# 1 2024-01-01 01:00:00      01:00:00               1539
# 2 2024-01-01 02:00:00      02:00:00                582
# 3 2024-01-01 03:00:00      03:00:00                257
# 4 2024-01-01 04:00:00      04:00:00                107
# 5 2024-01-01 05:00:00      05:00:00                190
# 6 2024-01-01 06:00:00      06:00:00                409
# 7 2024-01-01 07:00:00      07:00:00                356
# 8 2024-01-01 08:00:00      08:00:00                239
# 9 2024-01-01 09:00:00      09:00:00                302
#
#    numero_distrito_peatones distrito                        direccion  \
# 0                         1   Centro  Calle Arenal esquina San Martín
# 1                         1   Centro  Calle Arenal esquina San Martín
# 2                         1   Centro  Calle Arenal esquina San Martín
# 3                         1   Centro  Calle Arenal esquina San Martín
# 4                         1   Centro  Calle Arenal esquina San Martín
# 5                         1   Centro  Calle Arenal esquina San Martín
# 6                         1   Centro  Calle Arenal esquina San Martín
# 7                         1   Centro  Calle Arenal esquina San Martín
# 8                         1   Centro  Calle Arenal esquina San Martín
# 9                         1   Centro  Calle Arenal esquina San Martín
#
#       latitud    longitud
# 0  40.417,386  -3.707,141
# 1  40.417,386  -3.707,141
# 2  40.417,386  -3.707,141
# 3  40.417,386  -3.707,141
# 4  40.417,386  -3.707,141
# 5  40.417,386  -3.707,141
# 6  40.417,386  -3.707,141
# 7  40.417,386  -3.707,141
# 8  40.417,386  -3.707,141
# 9  40.417,386  -3.707,141

# %%
df_peatones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128833 entries, 0 to 128832
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   fecha_peatones            128833 non-null  datetime64[ns]
#  1   hora_peatones             128833 non-null  object
#  2   cantidad_peatones         128833 non-null  int64
#  3   numero_distrito_peatones  128833 non-null  int64
#  4   distrito                  128833 non-null  object
#  5   direccion                 128833 non-null  object
#  6   latitud                   128833 non-null  object
#  7   longitud                  128833 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 7.9+ MB

# %%
df_peatones.describe(include="all").T
# Out:
#                              count unique           top   freq  \
# fecha_peatones              128833    NaN           NaN    NaN
# hora_peatones               128833     24      20:00:00   5420
# cantidad_peatones         128833.0    NaN           NaN    NaN
# numero_distrito_peatones  128833.0    NaN           NaN    NaN
# distrito                    128833     13        Centro  63855
# direccion                   128833     30  Av. Albufera   4367
# latitud                     128833     29    40.494,945   8630
# longitud                    128833     29    -3.687,718   8630
#
#                                                    mean                  min  \
# fecha_peatones            2024-04-01 05:23:11.038010112  2024-01-01 00:00:00
# hora_peatones                                       NaN                  NaN
# cantidad_peatones                            650.328837                  0.0
# numero_distrito_peatones                       5.916008                  1.0
# distrito                                            NaN                  NaN
# direccion                                           NaN                  NaN
# latitud                                             NaN                  NaN
# longitud                                            NaN                  NaN
#
#                                           25%                  50%  \
# fecha_peatones            2024-02-16 03:00:00  2024-04-01 04:00:00
# hora_peatones                             NaN                  NaN
# cantidad_peatones                        66.0                299.0
# numero_distrito_peatones                  1.0                  4.0
# distrito                                  NaN                  NaN
# direccion                                 NaN                  NaN
# latitud                                   NaN                  NaN
# longitud                                  NaN                  NaN
#
#                                           75%                  max  \
# fecha_peatones            2024-05-16 14:00:00  2024-06-30 23:00:00
# hora_peatones                             NaN                  NaN
# cantidad_peatones                       750.0              11180.0
# numero_distrito_peatones                 10.0                 21.0
# distrito                                  NaN                  NaN
# direccion                                 NaN                  NaN
# latitud                                   NaN                  NaN
# longitud                                  NaN                  NaN
#
#                                   std
# fecha_peatones                    NaN
# hora_peatones                     NaN
# cantidad_peatones         1094.071783
# numero_distrito_peatones     5.938865
# distrito                          NaN
# direccion                         NaN
# latitud                           NaN
# longitud                          NaN

# %%
df_peatones.isnull().sum()
# Out:
# fecha_peatones              0
# hora_peatones               0
# cantidad_peatones           0
# numero_distrito_peatones    0
# distrito                    0
# direccion                   0
# latitud                     0
# longitud                    0
# dtype: int64

# %% [markdown]
# Duplicados para eliminar

# %%
df_peatones.duplicated().values.any()
# Out:
# np.False_

# %% [markdown]
# Volcado Datos

# %%
df_peatones.to_sql('flujo_peatones', schema='dw_tfm_restaurantes', con = conn, if_exists = 'append', index=False)
# Out:
# 833

# %%
count_db = pd.read_sql("SELECT COUNT(*) AS count FROM dw_tfm_restaurantes.flujo_peatones", conn).iloc[0, 0]
count_df = len(df_peatones)

print(f"Filas en DataFrame: {count_df}")
print(f"Filas en tabla dw_tfm_restaurantes: {count_db}")

if count_df == count_db:
    print("La carga se efectuó correctamente.")
else:
    print("Hay discrepancias en la cantidad de filas insertadas.")
# Out:
# Filas en DataFrame: 128833
# Filas en tabla dw_tfm_restaurantes: 128833
# La carga se efectuó correctamente.
